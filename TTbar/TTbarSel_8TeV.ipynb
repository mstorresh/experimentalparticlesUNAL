// %% [markdown]
// # An introductional notebook to HEP analysis in C++
//
// <p>In this notebook you can find an easy set of commands that show some basic computing techniques commonly used in High Energy Physics (HEP) analyzes.</p>
//
// <p>It also shows how to create an histogram, fill it and draw it. Moreover it is an introduction to [ROOT](https://root.cern.ch/) too. The final output is a plot with the number of leptons.</p>
//
// Based on ATLAS opendata notebooks (http://opendata.atlas.cern/release/2020/documentation/notebooks/intro.html)

// %% [markdown]
// The library used is [ROOT](https://root.cern.ch/), a scientific data analysis software framework that provides a large set of functionalities needed to deal with big data processing, statistical analysis, visualisation and storage.

// %% [markdown]
// <p>At first we have to include several helpers that will support our analysis:</p>

// %%
#include <iostream>
#include <string>
#include <stdio.h>

// %% [markdown]
// Next we have to open the data that we want to analyze. As described above the data is stored in a _*.root_ file. This is a root file containing tracks and calorimeter clusters

// %%
TFile *file = TFile::Open("Data_8TeV.root");

// %% [markdown]
// The next step is to define a tree named _tree_ to get the data out of the _*.root_ file. The tree in this root file is called "JetRecoTree". We will then print the contents of the tree to find the names of the variables.

// %%
TTree *tree = (TTree*) file->Get("mini");
tree->Print()
// Out:
// ******************************************************************************
// *Tree    :mini      : 4-vectors + variables required for scaling factors     *
// *Entries : 14945674 : Total =      3737586466 bytes  File  Size = 1366006484 *
// *        :          : Tree compression factor =   2.74                       *
// ******************************************************************************
// *Br    0 :runNumber : runNumber/I                                            *
// *Entries : 14945674 : Total  Size=   59789737 bytes  File Size  =     297928 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 200.68     *
// *............................................................................*
// *Br    1 :eventNumber : eventNumber/I                                        *
// *Entries : 14945674 : Total  Size=   59789885 bytes  File Size  =   44412272 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   1.35     *
// *............................................................................*
// *Br    2 :channelNumber : channelNumber/I                                    *
// *Entries : 14945674 : Total  Size=   59790033 bytes  File Size  =     298208 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 200.49     *
// *............................................................................*
// *Br    3 :mcWeight  : mcWeight/F                                             *
// *Entries : 14945674 : Total  Size=   59789663 bytes  File Size  =     268231 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.90     *
// *............................................................................*
// *Br    4 :pvxp_n    : pvxp_n/I                                               *
// *Entries : 14945674 : Total  Size=   59789515 bytes  File Size  =   13103705 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   4.56     *
// *............................................................................*
// *Br    5 :vxp_z     : vxp_z/F                                                *
// *Entries : 14945674 : Total  Size=   59789441 bytes  File Size  =   55540897 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   1.08     *
// *............................................................................*
// *Br    6 :scaleFactor_PILEUP : scaleFactor_PILEUP/F                          *
// *Entries : 14945674 : Total  Size=   59790403 bytes  File Size  =     268931 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.32     *
// *............................................................................*
// *Br    7 :scaleFactor_ELE : scaleFactor_ELE/F                                *
// *Entries : 14945674 : Total  Size=   59790181 bytes  File Size  =     268721 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.49     *
// *............................................................................*
// *Br    8 :scaleFactor_MUON : scaleFactor_MUON/F                              *
// *Entries : 14945674 : Total  Size=   59790255 bytes  File Size  =     268791 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.43     *
// *............................................................................*
// *Br    9 :scaleFactor_BTAG : scaleFactor_BTAG/F                              *
// *Entries : 14945674 : Total  Size=   59790255 bytes  File Size  =     268791 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.43     *
// *............................................................................*
// *Br   10 :scaleFactor_TRIGGER : scaleFactor_TRIGGER/F                        *
// *Entries : 14945674 : Total  Size=   59790477 bytes  File Size  =     269001 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.26     *
// *............................................................................*
// *Br   11 :scaleFactor_JVFSF : scaleFactor_JVFSF/F                            *
// *Entries : 14945674 : Total  Size=   59790329 bytes  File Size  =     268861 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.38     *
// *............................................................................*
// *Br   12 :scaleFactor_ZVERTEX : scaleFactor_ZVERTEX/F                        *
// *Entries : 14945674 : Total  Size=   59790477 bytes  File Size  =     269001 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression= 222.26     *
// *............................................................................*
// *Br   13 :trigE     : trigE/O                                                *
// *Entries : 14945674 : Total  Size=   14958761 bytes  File Size  =      79720 *
// *Baskets :      139 : Basket Size=     159744 bytes  Compression= 187.60     *
// *............................................................................*
// *Br   14 :trigM     : trigM/O                                                *
// *Entries : 14945674 : Total  Size=   14958761 bytes  File Size  =     104652 *
// *Baskets :      139 : Basket Size=     159744 bytes  Compression= 142.91     *
// *............................................................................*
// *Br   15 :passGRL   : passGRL/O                                              *
// *Entries : 14945674 : Total  Size=   14959047 bytes  File Size  =      80772 *
// *Baskets :      139 : Basket Size=     159744 bytes  Compression= 185.16     *
// *............................................................................*
// *Br   16 :hasGoodVertex : hasGoodVertex/O                                    *
// *Entries : 14945674 : Total  Size=   14959905 bytes  File Size  =     829254 *
// *Baskets :      139 : Basket Size=     159744 bytes  Compression=  18.04     *
// *............................................................................*
// *Br   17 :lep_n     : lep_n/i                                                *
// *Entries : 14945674 : Total  Size=   59789441 bytes  File Size  =    2971296 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=  20.12     *
// *............................................................................*
// *Br   18 :lep_truthMatched : lep_truthMatched[lep_n]/O                       *
// *Entries : 14945674 : Total  Size=   75857338 bytes  File Size  =   20999814 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   3.61     *
// *............................................................................*
// *Br   19 :lep_trigMatched : lep_trigMatched[lep_n]/s                         *
// *Entries : 14945674 : Total  Size=   91915976 bytes  File Size  =   24049899 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   3.82     *
// *............................................................................*
// *Br   20 :lep_pt    : lep_pt[lep_n]/F                                        *
// *Entries : 14945674 : Total  Size=  124039220 bytes  File Size  =   74690269 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.66     *
// *............................................................................*
// *Br   21 :lep_eta   : lep_eta[lep_n]/F                                       *
// *Entries : 14945674 : Total  Size=  124039432 bytes  File Size  =   77563362 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.60     *
// *............................................................................*
// *Br   22 :lep_phi   : lep_phi[lep_n]/F                                       *
// *Entries : 14945674 : Total  Size=  124039432 bytes  File Size  =   77598012 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.60     *
// *............................................................................*
// *Br   23 :lep_E     : lep_E[lep_n]/F                                         *
// *Entries : 14945674 : Total  Size=  124039008 bytes  File Size  =   75496519 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   24 :lep_z0    : lep_z0[lep_n]/F                                        *
// *Entries : 14945674 : Total  Size=  124039220 bytes  File Size  =   78351134 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   25 :lep_charge : lep_charge[lep_n]/F                                   *
// *Entries : 14945674 : Total  Size=  124040068 bytes  File Size  =   25355214 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   4.89     *
// *............................................................................*
// *Br   26 :lep_type  : lep_type[lep_n]/i                                      *
// *Entries : 14945674 : Total  Size=  124039637 bytes  File Size  =   18822849 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   6.59     *
// *............................................................................*
// *Br   27 :lep_flag  : lep_flag[lep_n]/i                                      *
// *Entries : 14945674 : Total  Size=  124039637 bytes  File Size  =   31625869 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   3.92     *
// *............................................................................*
// *Br   28 :lep_ptcone30 : lep_ptcone30[lep_n]/F                               *
// *Entries : 14945674 : Total  Size=  124040492 bytes  File Size  =   45473662 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   2.73     *
// *............................................................................*
// *Br   29 :lep_etcone20 : lep_etcone20[lep_n]/F                               *
// *Entries : 14945674 : Total  Size=  124040492 bytes  File Size  =   75793466 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.64     *
// *............................................................................*
// *Br   30 :lep_trackd0pvunbiased : lep_trackd0pvunbiased[lep_n]/F             *
// *Entries : 14945674 : Total  Size=  124042400 bytes  File Size  =   78337113 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.58     *
// *............................................................................*
// *Br   31 :lep_tracksigd0pvunbiased : lep_tracksigd0pvunbiased[lep_n]/F       *
// *Entries : 14945674 : Total  Size=  124043036 bytes  File Size  =   74120311 *
// *Baskets :      208 : Basket Size=    1224192 bytes  Compression=   1.67     *
// *............................................................................*
// *Br   32 :met_et    : met_et/F                                               *
// *Entries : 14945674 : Total  Size=   59789515 bytes  File Size  =   53578213 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   1.12     *
// *............................................................................*
// *Br   33 :met_phi   : met_phi/F                                              *
// *Entries : 14945674 : Total  Size=   59789589 bytes  File Size  =   55415952 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   1.08     *
// *............................................................................*
// *Br   34 :jet_n     : jet_n/i                                                *
// *Entries : 14945674 : Total  Size=   59789441 bytes  File Size  =    7425059 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   8.05     *
// *............................................................................*
// *Br   35 :alljet_n  : alljet_n/i                                             *
// *Entries : 14945674 : Total  Size=   59789663 bytes  File Size  =    7943976 *
// *Baskets :       70 : Basket Size=    1224192 bytes  Compression=   7.53     *
// *............................................................................*
// *Br   36 :jet_pt    : jet_pt[alljet_n]/F                                     *
// *Entries : 14945674 : Total  Size=   94527479 bytes  File Size  =   43503461 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.17     *
// *............................................................................*
// *Br   37 :jet_eta   : jet_eta[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   44933234 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.10     *
// *............................................................................*
// *Br   38 :jet_phi   : jet_phi[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   44929226 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.10     *
// *............................................................................*
// *Br   39 :jet_E     : jet_E[alljet_n]/F                                      *
// *Entries : 14945674 : Total  Size=   94527336 bytes  File Size  =   43801321 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.16     *
// *............................................................................*
// *Br   40 :jet_m     : jet_m[alljet_n]/F                                      *
// *Entries : 14945674 : Total  Size=   94527336 bytes  File Size  =   43460012 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.17     *
// *............................................................................*
// *Br   41 :jet_jvf   : jet_jvf[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   39392706 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.40     *
// *............................................................................*
// *Br   42 :jet_trueflav : jet_trueflav[alljet_n]/I                            *
// *Entries : 14945674 : Total  Size=   94528330 bytes  File Size  =   12915685 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   7.32     *
// *............................................................................*
// *Br   43 :jet_truthMatched : jet_truthMatched[alljet_n]/I                    *
// *Entries : 14945674 : Total  Size=   94528902 bytes  File Size  =   12893729 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   7.33     *
// *............................................................................*
// *Br   44 :jet_SV0   : jet_SV0[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   16306468 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   5.80     *
// *............................................................................*
// *Br   45 :jet_MV1   : jet_MV1[alljet_n]/F                                    *
// *Entries : 14945674 : Total  Size=   94527622 bytes  File Size  =   41303912 *
// *Baskets :      139 : Basket Size=    1224192 bytes  Compression=   2.29     *
// *............................................................................*

// %% [markdown]
// Activate variables

// %%
Bool_t e_trig;
Bool_t mu_trig;
Bool_t good_vtx;
UInt_t lep_n;
UInt_t jet_n;
Float_t MET;
Float_t MET_phi;

Float_t lep_pt[10];  
Float_t lep_eta[10];  
Float_t lep_phi[10];  
Float_t lep_E[10];  
Int_t lep_type[10];  
Float_t lep_ptcone30[10];
Float_t lep_etcone20[10];

Float_t jet_pt[10];  


tree->SetBranchAddress("trigE", &e_trig);
tree->SetBranchAddress("trigM", &mu_trig);
tree->SetBranchAddress("hasGoodVertex", &good_vtx);
tree->SetBranchAddress("lep_n", &lep_n);
tree->SetBranchAddress("jet_n", &jet_n);
tree->SetBranchAddress("met_et", &MET);
tree->SetBranchAddress("met_phi", &MET_phi);

tree->SetBranchAddress("lep_pt", &lep_pt);
tree->SetBranchAddress("lep_eta", &lep_eta);
tree->SetBranchAddress("lep_phi", &lep_phi);
tree->SetBranchAddress("lep_E", &lep_E);
tree->SetBranchAddress("lep_type", &lep_type);
tree->SetBranchAddress("lep_ptcone30", &lep_ptcone30);
tree->SetBranchAddress("lep_etcone20", &lep_etcone20);

tree->SetBranchAddress("jet_pt", &jet_pt);

// %% [markdown]
// Create Canvas

// %%
TCanvas *canvas = new TCanvas("Canvas","",800,600);

// %% [markdown]
// Create histograms: Leading jet pT and all jets pT

// %%
TH1F *cutflow = new TH1F("Cutflow","Cutflow; Cut; Events",10,0,10);

TH1F *hist_njets = new TH1F("Number of jets","n-jets; Jet multiplicity; Events",10,0,10);

// %% [markdown]
// Loop and fill histograms

// %%
int nentries, nbytes, i;
nentries = (Int_t)tree->GetEntries();

int cut1 = 0;
int cut2 = 0;
int cut3 = 0;
int cut4 = 0;
int cut5 = 0;
int cut6 = 0;
int cut7 = 0;
int cut8 = 0;


for (i = 0; i < nentries; i++)
{
    nbytes = tree->GetEntry(i);   

    //First cut: Good vertex
    if(!good_vtx) continue;
    cut1++;
    cutflow->Fill(1);

    //Second cut: Trigger
    if(!e_trig && !mu_trig) continue;
    cut2++;
    cutflow->Fill(2);
        
    // Preselection of good leptons                                                                                
    int n_mu=0;
    int n_el=0;
    int n_lep=0;

    //Loop over leptons
    for(unsigned int i=0; i<lep_n; i++){
        if( lep_pt[i] < 25000.) continue; 
        if( lep_ptcone30[i]/lep_pt[i] > 0.15 ) continue; 
        if( lep_etcone20[i]/lep_pt[i] > 0.15 ) continue;  
        if( lep_type [i]==13 && TMath::Abs(lep_eta[i]) < 2.5 ){
            n_mu++;}
        /*
        To complete: Add electrons and extract the index for the good lepton
        */
        }
    
     //Select events with only 1 good lepton and fill the cutflow histogram 
    //Example:
    //Third cut (one good lepton):
    if(n_lep!=1) continue;
    cutflow->Fill(3); 
    cut3++;
  
    
    int n_jets=0;
    int n_bjets=0;
    
    //Number of jets distribution
    hist_njets->Fill(jet_n,evtw);

    //Fourth cut: At least 4 jets
    if(jet_n<4) continue; 
    cutflow->Fill(4); 
    cut4++;

    for(unsigned int j=0; j<jet_n; j++){
        // To complete: apply jet cuts to find the good jets
        if(jet_pt[j] < 25000.) continue;
        //Eta cut
        // JVF cleaning 
        //n_jets++;
        // cut on 0.7892 MV1 and count the number of b-jets
        //n_bjets++;
        }
    
    //Fifth cut: At least 4 good jets
    if(n_jets<4) continue; 
    cutflow->Fill(5); 
    cut5++;
    
    //Sixth cut: at least one b-jet
    if(n_bjets==0) continue;
    //cutflow
    
    //Seventh cut: MET > 30 GeV
    if(MET<30000.) continue;
    //cutflow
    
    // TLorentzVector definitions                                                               
    TLorentzVector Lepton  = TLorentzVector();
    TLorentzVector  MeT  = TLorentzVector();

    //To complete: Lorentz vectors for the lepton and MET. Use SetPtEtaPhiE().

    //Calculation of the mTW using TLorentz vectors             
   // float mTW = sqrt(2*Lepton.Pt()*MeT.Et()*(1-cos(Lepton.DeltaPhi(MeT))));

    //Eight cut: mTW > 30 GeV
    
}

std::cout << "Done!" << std::endl;
std::cout << "All events:" << nentries << std::endl;
std::cout << "Cut1:" << cut1 << std::endl;
std::cout << "Cut2:" << cut2 << std::endl;
std::cout << "Cut3:" << cut3 << std::endl;
std::cout << "Cut4:" << cut4 << std::endl;
std::cout << "Cut5:" << cut5 << std::endl;
std::cout << "Cut6:" << cut6 << std::endl;
std::cout << "Cut7:" << cut7 << std::endl;
std::cout << "Cut8:" << cut8 << std::endl;
// Out:
// Done!
// All events:14945674
// Cut1:14656440
// Cut2:14656440
// Cut3:0
// Cut4:0
// Cut5:0
// Cut6:0
// Cut7:0
// Cut8:0

// %% [markdown]
// <p>Draw</p>

// %%
cutflow->Draw("");
canvas->Draw();
// Out:
// Thread 13 (Thread 0x7ff8b2c3f700 (LWP 120789)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=80, events=0x7ff8b2c3e1f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 12 (Thread 0x7ff8b3440700 (LWP 120788)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=78, events=0x7ff8b343f1f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 11 (Thread 0x7ff8b3c41700 (LWP 120787)):
// #0  0x00007ff8f039daff in __GI___poll (fds=0x7ff8b3c40560, nfds=1, timeout=-1) at ../sysdeps/unix/sysv/linux/poll.c:29
// #1  0x00007ff8dd8f918c in zmq::signaler_t::wait(int) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd8de51d in zmq::mailbox_t::recv(zmq::command_t*, int) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8dd8fa787 in zmq::socket_base_t::process_commands(int, bool) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #4  0x00007ff8dd8fb4bb in zmq::socket_base_t::recv(zmq::msg_t*, int) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #5  0x00007ff8dd91d1aa in s_recvmsg(zmq::socket_base_t*, zmq_msg_t*, int) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #6  0x00007ff8dd812ad5 in __pyx_f_3zmq_7backend_6cython_6socket_6Socket_recv () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/socket.cpython-38-x86_64-linux-gnu.so
// #7  0x00007ff8dd814325 in __pyx_pw_3zmq_7backend_6cython_6socket_6Socket_29recv () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/socket.cpython-38-x86_64-linux-gnu.so
// #8  0x00007ff8e807507e in __Pyx_CyFunction_CallAsMethod () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/error.cpython-38-x86_64-linux-gnu.so
// #9  0x000056141efcd25f in _PyObject_MakeTpCall (callable=0x7ff8dd95d040, args=<optimized out>, nargs=<optimized out>, keywords=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:159
// #10 0x000056141f01b8a1 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=1, args=0x7ff8dc3735c0, callable=0x7ff8dd95d040) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:125
// #11 method_vectorcall (method=<optimized out>, args=0x7ff8dc3735c8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:60
// #12 0x000056141ef8f58e in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3735c8, callable=0x7ff8dc0a3b80) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #13 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x7ff8d0005370) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #14 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3469
// #15 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #16 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3775b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #17 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3775b8, callable=0x7ff8dd3df1f0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #18 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x7ff8d0005370) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #19 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #20 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #21 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc366c38, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #22 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc366c38, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #23 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x7ff8d0005370) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #24 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #25 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #26 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8b3c40df8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #27 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8b3c40df8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #28 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #29 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dc37c180, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #30 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dc0a77b0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #31 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #32 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #33 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 10 (Thread 0x7ff8d4dd7700 (LWP 119137)):
// #0  0x00007ff8f03a012b in __GI___select (nfds=0, readfds=0x0, writefds=0x0, exceptfds=0x0, timeout=0x7ff8d4dd6920) at ../sysdeps/unix/sysv/linux/select.c:41
// #1  0x000056141f0c6643 in pysleep (secs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/timemodule.c:1849
// #2  time_sleep (self=<optimized out>, obj=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/timemodule.c:338
// #3  0x000056141efd01c5 in cfunction_vectorcall_O (func=0x7ff8ef898090, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/methodobject.c:482
// #4  0x000056141ef8f58e in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3643c0, callable=0x7ff8ef898090) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #5  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a15570) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #6  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3469
// #7  0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #8  _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3ad3b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #9  0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3ad3b8, callable=0x7ff8dd530af0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #10 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a15570) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #11 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #12 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #13 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc35efb8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #14 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc35efb8, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #15 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a15570) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #16 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #17 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #18 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d4dd6df8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #19 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d4dd6df8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #20 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #21 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd3de540, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #22 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dc35cb70) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #23 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #24 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #25 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 9 (Thread 0x7ff8d55d8700 (LWP 119136)):
// #0  futex_abstimed_wait_cancelable (private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7ff8c40011f0) at ../sysdeps/nptl/futex-internal.h:320
// #1  do_futex_wait (sem=sem
// entry=0x7ff8c40011f0, abstime=0x0, clockid=0) at sem_waitcommon.c:112
// #2  0x00007ff8f048d4e8 in __new_sem_wait_slow (sem=0x7ff8c40011f0, abstime=0x0, clockid=0) at sem_waitcommon.c:184
// #3  0x000056141efd2369 in PyThread_acquire_lock_timed (lock=0x7ff8c40011f0, microseconds=-1000000, intr_flag=1) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:459
// #4  0x000056141f03ff3a in acquire_timed (timeout=-1000000000, lock=0x7ff8c40011f0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:63
// #5  lock_PyThread_acquire_lock (self=0x7ff8dc35ca80, args=<optimized out>, kwds=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:146
// #6  0x000056141f034a07 in method_vectorcall_VARARGS_KEYWORDS (func=<optimized out>, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/descrobject.c:332
// #7  0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8c4001178, callable=0x7ff8ef8c9c20) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #8  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #9  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #10 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef64a7c0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8dc346bf0, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef649628, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8ef87f770, qualname=0x7ff8ef64b2f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #11 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc346be8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #12 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc346be8, callable=0x7ff8ef65c0d0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #13 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #14 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #15 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ee137190, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8dc347f48, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ee139098, defcount=2, kwdefs=0x0, closure=0x0, name=0x7ff8ef8f0d30, qualname=0x7ff8ee134cb0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #16 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc347f40, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #17 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc347f40, callable=0x7ff8ee135a60) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #18 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #19 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #20 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #21 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3469b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #22 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3469b8, callable=0x7ff8dd982040) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #23 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #24 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #25 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #26 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc35e1b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #27 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc35e1b8, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #28 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #29 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #30 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #31 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d55d7df8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #32 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d55d7df8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #33 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #34 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd3de7c0, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #35 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dc35c9f0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #36 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #37 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #38 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 8 (Thread 0x7ff8d5dd9700 (LWP 119135)):
// #0  0x00007ff8f036ddff in __GI___wait4 (pid=122960, stat_loc=stat_loc
// entry=0x7ff8d5dd5588, options=options
// entry=0, usage=usage
// entry=0x0) at ../sysdeps/unix/sysv/linux/wait4.c:27
// #1  0x00007ff8f036dd7b in __GI___waitpid (pid=<optimized out>, stat_loc=stat_loc
// entry=0x7ff8d5dd5588, options=options
// entry=0) at waitpid.c:38
// #2  0x00007ff8f02dd0e7 in do_system (line=<optimized out>) at ../sysdeps/posix/system.c:172
// #3  0x00007ff8ed04aa9e in TUnixSystem::StackTrace() () from /home/mstorresh/Root/root-6.20.04/build/lib/libCore.so
// #4  0x00007ff8e99f6070 in cling::MultiplexInterpreterCallbacks::PrintStackTrace() () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #5  0x00007ff8e99f5a76 in cling_runtime_internal_throwIfInvalidPointer () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #6  0x00007ff8dc00c0db in ?? ()
// #7  0x00007ff8d5dd7ce0 in ?? ()
// #8  0x00007ff8e99f59e0 in ?? () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #9  0x00005614216fe5a0 in ?? ()
// #10 0x00007ff8c08f4ed8 in ?? ()
// #11 0x00007ff8e99f59e0 in ?? () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #12 0x00007ff8d5dd80d0 in ?? ()
// #13 0x00005614217d3550 in ?? ()
// #14 0x00007ff8e9a70de4 in cling::IncrementalExecutor::executeWrapper(llvm::StringRef, cling::Value*) const () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #15 0x00007ff8e99f7c97 in cling::Interpreter::RunFunction(clang::FunctionDecl const*, cling::Value*) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #16 0x00007ff8e99f996d in cling::Interpreter::EvaluateInternal(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, cling::CompilationOptions, cling::Value*, cling::Transaction**, unsigned long) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #17 0x00007ff8e99f9c89 in cling::Interpreter::process(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, cling::Value*, cling::Transaction**, bool) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #18 0x00007ff8e9ac398d in cling::MetaProcessor::process(llvm::StringRef, cling::Interpreter::CompilationResult&, cling::Value*, bool) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #19 0x00007ff8e995a1dc in HandleInterpreterException(cling::MetaProcessor*, char const*, cling::Interpreter::CompilationResult&, cling::Value*) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #20 0x00007ff8e99719db in TCling::ProcessLine(char const*, TInterpreter::EErrorCode*) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #21 0x00007ff8eca118cf in JupyROOTExecutorImpl(char const*) () from /home/mstorresh/Root/root-6.20.04/build/lib/libJupyROOT.so
// #22 0x00007ff8eca1198d in JupyROOTExecutor () from /home/mstorresh/Root/root-6.20.04/build/lib/libJupyROOT.so
// #23 0x00007ff8ee0959dd in ffi_call_unix64 () from /home/mstorresh/anaconda3/lib/python3.8/lib-dynload/../../libffi.so.7
// #24 0x00007ff8ee095067 in ffi_call_int () from /home/mstorresh/anaconda3/lib/python3.8/lib-dynload/../../libffi.so.7
// #25 0x00007ff8ee0ab97a in _call_function_pointer (argcount=1, resmem=0x7ff8d5dd8600, restype=<optimized out>, atypes=<optimized out>, avalues=0x7ff8d5dd85e0, pProc=0x7ff8eca11980 <JupyROOTExecutor>, flags=4353) at /usr/local/src/conda/python-3.8.3/Modules/_ctypes/callproc.c:871
// #26 _ctypes_callproc (pProc=<optimized out>, argtuple=<optimized out>, flags=<optimized out>, argtypes=<optimized out>, restype=<optimized out>, checker=<optimized out>) at /usr/local/src/conda/python-3.8.3/Modules/_ctypes/callproc.c:1199
// #27 0x00007ff8ee0ac0db in PyCFuncPtr_call (self=<optimized out>, inargs=<optimized out>, kwds=0x0) at /usr/local/src/conda/python-3.8.3/Modules/_ctypes/_ctypes.c:4201
// #28 0x000056141efcd25f in _PyObject_MakeTpCall (callable=0x7ff8dc3aa340, args=<optimized out>, nargs=<optimized out>, keywords=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:159
// #29 0x000056141f055719 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3467c8, callable=0x7ff8dc3aa340) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:125
// #30 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a3b9f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #31 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3469
// #32 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=2, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #33 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc347be0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #34 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc347be0, callable=0x7ff8dd9821f0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #35 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a3b9f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #36 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #37 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #38 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3465b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #39 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3465b8, callable=0x7ff8dd982040) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #40 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a3b9f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #41 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #42 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #43 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3b7fb8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #44 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3b7fb8, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #45 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a3b9f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #46 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #47 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #48 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d5dd8df8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #49 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d5dd8df8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #50 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #51 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd3de580, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #52 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dc35c5a0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #53 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #54 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #55 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 7 (Thread 0x7ff8d67fc700 (LWP 119071)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=29, events=0x7ff8d67fb1f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 6 (Thread 0x7ff8d6ffd700 (LWP 119070)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=27, events=0x7ff8d6ffc1f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 5 (Thread 0x7ff8d77fe700 (LWP 119069)):
// #0  0x00007ff8f039daff in __GI___poll (fds=0x7ff8d77fd5f0, nfds=2, timeout=-1) at ../sysdeps/unix/sysv/linux/poll.c:29
// #1  0x00007ff8dd91e27c in zmq_poll () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd8ef772 in zmq::proxy(zmq::socket_base_t*, zmq::socket_base_t*, zmq::socket_base_t*, zmq::socket_base_t*) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8dd7c8a3b in __pyx_pw_3zmq_7backend_6cython_7_device_3proxy () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/_device.cpython-38-x86_64-linux-gnu.so
// #4  0x00007ff8dd7ca809 in __pyx_pw_3zmq_7backend_6cython_7_device_1device () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/_device.cpython-38-x86_64-linux-gnu.so
// #5  0x000056141efcd25f in _PyObject_MakeTpCall (callable=0x7ff8dd95d6c0, args=<optimized out>, nargs=<optimized out>, keywords=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:159
// #6  0x000056141f055719 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3c7f58, callable=0x7ff8dd95d6c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:125
// #7  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423462670) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #8  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3469
// #9  0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #10 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3c5bb8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #11 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3c5bb8, callable=0x7ff8dd551dc0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #12 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423462670) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #13 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #14 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #15 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3d3378, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #16 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3d3378, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #17 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423462670) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #18 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #19 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #20 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d77fddf8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #21 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d77fddf8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #22 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #23 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8ef140480, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #24 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dd431870) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #25 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #26 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #27 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 4 (Thread 0x7ff8d7fff700 (LWP 119068)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=19, events=0x7ff8dc0a2ba0, maxevents=3, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8f04a816c in select_epoll_poll_impl.isra.4 (maxevents=<optimized out>, timeout_obj=<optimized out>) at /usr/local/src/conda/python-3.8.3/Modules/selectmodule.c:1558
// #2  select_epoll_poll (self=0x7ff8dd42c730, args=<optimized out>, nargs=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.8.3/Modules/clinic/selectmodule.c.h:859
// #3  0x000056141efff650 in method_vectorcall_FASTCALL_KEYWORDS (func=<optimized out>, args=0x561424dfc938, nargsf=<optimized out>, kwnames=0x0) at /tmp/build/80754af9/python_1593706424329/work/Objects/descrobject.c:371
// #4  0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561424dfc938, callable=0x7ff8ef6d7900) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #5  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #6  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #7  0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef4e9ea0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8d00011c0, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef4e6a48, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8ef6d5330, qualname=0x7ff8ef4ea670) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #8  0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d00011b0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #9  0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8d00011b0, callable=0x7ff8ef4f1430) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #10 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #11 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #12 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #13 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3ce760, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #14 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3ce760, callable=0x7ff8ee7a6c10) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #15 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #16 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #17 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #18 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3ce580, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #19 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3ce580, callable=0x7ff8ee7a50d0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #20 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #21 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #22 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #23 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3d1358, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #24 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3d1358, callable=0x7ff8dd6e2790) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #25 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #26 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #27 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #28 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d7ffe8c8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #29 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d7ffe8c8, callable=0x7ff8dd54f790) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #30 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #31 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd43f840, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #32 0x000056141f0531dc in do_call_core (kwdict=0x7ff8dd43f940, callargs=0x7ff8ef8e0040, func=0x7ff8dd43f840, tstate=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:5010
// #33 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3559
// #34 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #35 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3c57b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #36 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3c57b8, callable=0x7ff8ef65f430) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #37 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #38 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #39 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #40 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3ca8b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #41 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3ca8b8, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #42 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #43 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #44 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #45 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d7ffedf8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #46 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d7ffedf8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #47 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #48 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd436d00, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #49 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dd4315d0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #50 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #51 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #52 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 3 (Thread 0x7ff8dcbc2700 (LWP 119067)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=10, events=0x7ff8dcbc11f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 2 (Thread 0x7ff8dd3c3700 (LWP 119066)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=8, events=0x7ff8dd3c21f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 1 (Thread 0x7ff8f011e740 (LWP 119047)):
// #0  0x00007ff8f03a012b in __GI___select (nfds=0, readfds=0x0, writefds=0x0, exceptfds=0x0, timeout=0x7ffee3a14580) at ../sysdeps/unix/sysv/linux/select.c:41
// #1  0x000056141f0c6643 in pysleep (secs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/timemodule.c:1849
// #2  time_sleep (self=<optimized out>, obj=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/timemodule.c:338
// #3  0x000056141efd01c5 in cfunction_vectorcall_O (func=0x7ff8ef898090, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/methodobject.c:482
// #4  0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3791e0, callable=0x7ff8ef898090) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #5  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #6  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #7  0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8e80ce5b0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x5614249cbda0, kwcount=<optimized out>, kwstep=1, defs=0x7ff8e80cd398, defcount=2, kwdefs=0x0, closure=0x0, name=0x7ff8e80cc850, qualname=0x7ff8e80cc850) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #8  0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x5614249cbd70, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #9  0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x5614249cbd70, callable=0x7ff8e80cb940) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #10 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #11 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #12 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8e80ce3a0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x56142341e0e8, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef6c2bc8, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8e809b4e0, qualname=0x7ff8e80a53f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// ...
// #90 0x000056141f0babde in partial_fastcall.isra.2 (kwargs=0x0, nargs=<optimized out>, args=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/_functoolsmodule.c:169
// #91 partial_call (pto=0x7ff8dc08a810, args=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/_functoolsmodule.c:224
// #92 0x000056141efcd25f in _PyObject_MakeTpCall (callable=0x7ff8dc08a810, args=<optimized out>, nargs=<optimized out>, keywords=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:159
// #93 0x000056141f0515e5 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3777d0, callable=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:125
// #94 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #95 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #96 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=2, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #97 _PyFunction_Vectorcall (func=<optimized out>, stack=0x561424aa8630, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #98 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561424aa8630, callable=0x7ff8dd6cd4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #99 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #100 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #101 0x000056141f01a7af in _PyEval_EvalCodeWithName (_co=0x7ff8dd76a3a0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8dd4205e8, kwcount=<optimized out>, kwstep=1, defs=0x0, defcount=0, kwdefs=0x0, closure=0x7ff8dc389280, name=0x7ff8ef7a6cb0, qualname=0x7ff8dd766390) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #102 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd4205e0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #103 0x000056141ef0def9 in _PyObject_Vectorcall (callable=0x7ff8dc3b9310, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #104 0x000056141ef1c0a7 in context_run (self=0x7ff8dc37e840, args=0x7ff8dd4205d8, nargs=2, kwnames=0x0) at /tmp/build/80754af9/python_1593706424329/work/Python/context.c:634
// #105 0x000056141efd0344 in cfunction_vectorcall_FASTCALL_KEYWORDS (func=0x7ff8dc0960e0, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/methodobject.c:437
// #106 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dc0960e0, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #107 0x000056141f056611 in do_call_core (kwdict=0x0, callargs=0x7ff8dd4205c0, func=0x7ff8dc0960e0, tstate=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4983
// #108 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3559
// #109 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #110 _PyFunction_Vectorcall (func=<optimized out>, stack=0x561424d41c08, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #111 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561424d41c08, callable=0x7ff8ee86d430) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #112 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #113 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #114 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #115 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3681c0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #116 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3681c0, callable=0x7ff8ee7a6c10) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #117 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #118 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #119 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #120 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc345ee0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #121 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc345ee0, callable=0x7ff8ee7a50d0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #122 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #123 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #124 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #125 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8ef5b4bc8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #126 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8ef5b4bc8, callable=0x7ff8dd6e2790) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #127 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #128 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #129 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #130 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8eec4d9d0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #131 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8eec4d9d0, callable=0x7ff8dd534c10) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #132 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #133 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #134 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef158190, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x7ff8ef6c2b68, kwargs=0x7ff8dd5031b8, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef06ace8, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8ef06bc30, qualname=0x7ff8ef06d530) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #135 0x000056141f01b620 in _PyFunction_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, stack=0x7ff8dd5031b0, func=0x7ff8ef004b80) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #136 _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=0x7ff8dd5031b0, callable=0x7ff8ef004b80) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #137 method_vectorcall (method=<optimized out>, args=0x7ff8dd5031b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:60
// #138 0x000056141ef9050b in _PyObject_Vectorcall (kwnames=0x7ff8ef6c2b50, nargsf=<optimized out>, args=<optimized out>, callable=0x7ff8ef1af280) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #139 call_function (kwnames=0x7ff8ef6c2b50, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #140 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3515
// #141 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=0, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #142 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8ef780db0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #143 0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8ef780db0, callable=0x7ff8dd4155e0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #144 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #145 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #146 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8e80cedf0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x0, kwcount=<optimized out>, kwstep=2, defs=0x0, defcount=0, kwdefs=0x0, closure=0x0, name=0x0, qualname=0x0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #147 0x000056141f01b054 in PyEval_EvalCodeEx (_co=<optimized out>, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kws=<optimized out>, kwcount=0, defs=0x0, defcount=0, kwdefs=0x0, closure=0x0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4327
// #148 0x000056141f0a95bc in PyEval_EvalCode (co=<optimized out>, globals=<optimized out>, locals=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:718
// #149 0x000056141f0de6f3 in builtin_exec_impl.isra.14 (locals=0x7ff8ef8910c0, globals=0x7ff8ef8910c0, source=0x7ff8e80cedf0) at /tmp/build/80754af9/python_1593706424329/work/Python/bltinmodule.c:1033
// #150 builtin_exec (module=<optimized out>, args=<optimized out>, nargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/clinic/bltinmodule.c.h:396
// #151 0x000056141efd0039 in cfunction_vectorcall_FASTCALL (func=0x7ff8ef8af590, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/methodobject.c:422
// #152 0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561421cc5ad0, callable=0x7ff8ef8af590) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #153 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #154 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #155 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef73c0e0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x561421159c80, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef72b5a8, defcount=5, kwdefs=0x0, closure=0x0, name=0x7ff8ef72f4f0, qualname=0x7ff8ef72f4f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #156 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x561421159c58, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #157 0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561421159c58, callable=0x7ff8ef71b940) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #158 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #159 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #160 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef743450, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8ef7412a8, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef7e7dd8, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8ef72b490, qualname=0x7ff8ef72b490) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #161 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8ef741298, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #162 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8ef6c3b80, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #163 0x000056141f0dbf76 in pymain_run_module (modname=<optimized out>, set_argv0=1) at /tmp/build/80754af9/python_1593706424329/work/Modules/main.c:308
// #164 0x000056141f0de1b7 in pymain_run_python (exitcode=0x7ffee3a17d80) at /tmp/build/80754af9/python_1593706424329/work/Modules/main.c:565
// #165 Py_RunMain () at /tmp/build/80754af9/python_1593706424329/work/Modules/main.c:650
// #166 0x000056141f0de389 in Py_BytesMain (argc=<optimized out>, argv=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/main.c:1096
// #167 0x00007ff8f02af0b3 in __libc_start_main (main=0x56141efa6040 <main>, argc=5, argv=0x7ffee3a17f88, init=<optimized out>, fini=<optimized out>, rtld_fini=<optimized out>, stack_end=0x7ffee3a17f78) at ../csu/libc-start.c:308
// #168 0x000056141f06e553 in _start () at ../sysdeps/x86_64/elf/start.S:103
// Error in <HandleInterpreterException>: Trying to access a pointer that points to an invalid memory address..
// Execution of your code was aborted.
// input_line_151:3:1: warning: invalid memory pointer passed to a callee:
// canvas->Draw();
// ^~~~~~

// %%
hist_njets->Draw();
canvas->Draw();
// Out:
// Thread 13 (Thread 0x7ff8b2c3f700 (LWP 120789)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=80, events=0x7ff8b2c3e1f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 12 (Thread 0x7ff8b3440700 (LWP 120788)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=78, events=0x7ff8b343f1f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 11 (Thread 0x7ff8b3c41700 (LWP 120787)):
// #0  0x00007ff8f039daff in __GI___poll (fds=0x7ff8b3c40560, nfds=1, timeout=-1) at ../sysdeps/unix/sysv/linux/poll.c:29
// #1  0x00007ff8dd8f918c in zmq::signaler_t::wait(int) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd8de51d in zmq::mailbox_t::recv(zmq::command_t*, int) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8dd8fa787 in zmq::socket_base_t::process_commands(int, bool) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #4  0x00007ff8dd8fb4bb in zmq::socket_base_t::recv(zmq::msg_t*, int) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #5  0x00007ff8dd91d1aa in s_recvmsg(zmq::socket_base_t*, zmq_msg_t*, int) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #6  0x00007ff8dd812ad5 in __pyx_f_3zmq_7backend_6cython_6socket_6Socket_recv () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/socket.cpython-38-x86_64-linux-gnu.so
// #7  0x00007ff8dd814325 in __pyx_pw_3zmq_7backend_6cython_6socket_6Socket_29recv () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/socket.cpython-38-x86_64-linux-gnu.so
// #8  0x00007ff8e807507e in __Pyx_CyFunction_CallAsMethod () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/error.cpython-38-x86_64-linux-gnu.so
// #9  0x000056141efcd25f in _PyObject_MakeTpCall (callable=0x7ff8dd95d040, args=<optimized out>, nargs=<optimized out>, keywords=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:159
// #10 0x000056141f01b8a1 in _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=1, args=0x7ff8dc3735c0, callable=0x7ff8dd95d040) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:125
// #11 method_vectorcall (method=<optimized out>, args=0x7ff8dc3735c8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:60
// #12 0x000056141ef8f58e in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3735c8, callable=0x7ff8dc0a3b80) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #13 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x7ff8d0005370) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #14 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3469
// #15 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #16 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3775b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #17 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3775b8, callable=0x7ff8dd3df1f0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #18 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x7ff8d0005370) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #19 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #20 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #21 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc366c38, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #22 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc366c38, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #23 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x7ff8d0005370) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #24 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #25 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #26 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8b3c40df8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #27 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8b3c40df8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #28 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #29 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dc37c180, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #30 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dc0a77b0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #31 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #32 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #33 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 10 (Thread 0x7ff8d4dd7700 (LWP 119137)):
// #0  0x00007ff8f03a012b in __GI___select (nfds=0, readfds=0x0, writefds=0x0, exceptfds=0x0, timeout=0x7ff8d4dd6920) at ../sysdeps/unix/sysv/linux/select.c:41
// #1  0x000056141f0c6643 in pysleep (secs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/timemodule.c:1849
// #2  time_sleep (self=<optimized out>, obj=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/timemodule.c:338
// #3  0x000056141efd01c5 in cfunction_vectorcall_O (func=0x7ff8ef898090, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/methodobject.c:482
// #4  0x000056141ef8f58e in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3643c0, callable=0x7ff8ef898090) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #5  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a15570) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #6  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3469
// #7  0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #8  _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3ad3b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #9  0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3ad3b8, callable=0x7ff8dd530af0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #10 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a15570) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #11 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #12 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #13 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc35efb8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #14 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc35efb8, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #15 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a15570) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #16 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #17 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #18 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d4dd6df8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #19 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d4dd6df8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #20 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #21 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd3de540, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #22 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dc35cb70) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #23 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #24 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #25 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 9 (Thread 0x7ff8d55d8700 (LWP 119136)):
// #0  futex_abstimed_wait_cancelable (private=0, abstime=0x0, clockid=0, expected=0, futex_word=0x7ff8c40011f0) at ../sysdeps/nptl/futex-internal.h:320
// #1  do_futex_wait (sem=sem
// entry=0x7ff8c40011f0, abstime=0x0, clockid=0) at sem_waitcommon.c:112
// #2  0x00007ff8f048d4e8 in __new_sem_wait_slow (sem=0x7ff8c40011f0, abstime=0x0, clockid=0) at sem_waitcommon.c:184
// #3  0x000056141efd2369 in PyThread_acquire_lock_timed (lock=0x7ff8c40011f0, microseconds=-1000000, intr_flag=1) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:459
// #4  0x000056141f03ff3a in acquire_timed (timeout=-1000000000, lock=0x7ff8c40011f0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:63
// #5  lock_PyThread_acquire_lock (self=0x7ff8dc35ca80, args=<optimized out>, kwds=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:146
// #6  0x000056141f034a07 in method_vectorcall_VARARGS_KEYWORDS (func=<optimized out>, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/descrobject.c:332
// #7  0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8c4001178, callable=0x7ff8ef8c9c20) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #8  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #9  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #10 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef64a7c0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8dc346bf0, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef649628, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8ef87f770, qualname=0x7ff8ef64b2f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #11 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc346be8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #12 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc346be8, callable=0x7ff8ef65c0d0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #13 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #14 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #15 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ee137190, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8dc347f48, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ee139098, defcount=2, kwdefs=0x0, closure=0x0, name=0x7ff8ef8f0d30, qualname=0x7ff8ee134cb0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #16 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc347f40, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #17 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc347f40, callable=0x7ff8ee135a60) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #18 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #19 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #20 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #21 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3469b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #22 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3469b8, callable=0x7ff8dd982040) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #23 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #24 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #25 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #26 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc35e1b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #27 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc35e1b8, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #28 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614249d1c30) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #29 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #30 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #31 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d55d7df8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #32 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d55d7df8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #33 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #34 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd3de7c0, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #35 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dc35c9f0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #36 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #37 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #38 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 8 (Thread 0x7ff8d5dd9700 (LWP 119135)):
// #0  0x00007ff8f036ddff in __GI___wait4 (pid=124719, stat_loc=stat_loc
// entry=0x7ff8d5dd5588, options=options
// entry=0, usage=usage
// entry=0x0) at ../sysdeps/unix/sysv/linux/wait4.c:27
// #1  0x00007ff8f036dd7b in __GI___waitpid (pid=<optimized out>, stat_loc=stat_loc
// entry=0x7ff8d5dd5588, options=options
// entry=0) at waitpid.c:38
// #2  0x00007ff8f02dd0e7 in do_system (line=<optimized out>) at ../sysdeps/posix/system.c:172
// #3  0x00007ff8ed04aa9e in TUnixSystem::StackTrace() () from /home/mstorresh/Root/root-6.20.04/build/lib/libCore.so
// #4  0x00007ff8e99f6070 in cling::MultiplexInterpreterCallbacks::PrintStackTrace() () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #5  0x00007ff8e99f5a76 in cling_runtime_internal_throwIfInvalidPointer () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #6  0x00007ff8dc00a0db in ?? ()
// #7  0x00007ff8d5dd7ce0 in ?? ()
// #8  0x00007ff8e99f59e0 in ?? () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #9  0x00005614216fe5a0 in ?? ()
// #10 0x00007ff8c08f58b0 in ?? ()
// #11 0x00007ff8e99f59e0 in ?? () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #12 0x00007ff8d5dd80d0 in ?? ()
// #13 0x00005614217d3550 in ?? ()
// #14 0x00007ff8e9a70de4 in cling::IncrementalExecutor::executeWrapper(llvm::StringRef, cling::Value*) const () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #15 0x00007ff8e99f7c97 in cling::Interpreter::RunFunction(clang::FunctionDecl const*, cling::Value*) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #16 0x00007ff8e99f996d in cling::Interpreter::EvaluateInternal(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, cling::CompilationOptions, cling::Value*, cling::Transaction**, unsigned long) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #17 0x00007ff8e99f9c89 in cling::Interpreter::process(std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> > const&, cling::Value*, cling::Transaction**, bool) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #18 0x00007ff8e9ac398d in cling::MetaProcessor::process(llvm::StringRef, cling::Interpreter::CompilationResult&, cling::Value*, bool) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #19 0x00007ff8e995a1dc in HandleInterpreterException(cling::MetaProcessor*, char const*, cling::Interpreter::CompilationResult&, cling::Value*) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #20 0x00007ff8e99719db in TCling::ProcessLine(char const*, TInterpreter::EErrorCode*) () from /home/mstorresh/Root/root-6.20.04/build/lib/libCling.so
// #21 0x00007ff8eca118cf in JupyROOTExecutorImpl(char const*) () from /home/mstorresh/Root/root-6.20.04/build/lib/libJupyROOT.so
// #22 0x00007ff8eca1198d in JupyROOTExecutor () from /home/mstorresh/Root/root-6.20.04/build/lib/libJupyROOT.so
// #23 0x00007ff8ee0959dd in ffi_call_unix64 () from /home/mstorresh/anaconda3/lib/python3.8/lib-dynload/../../libffi.so.7
// #24 0x00007ff8ee095067 in ffi_call_int () from /home/mstorresh/anaconda3/lib/python3.8/lib-dynload/../../libffi.so.7
// #25 0x00007ff8ee0ab97a in _call_function_pointer (argcount=1, resmem=0x7ff8d5dd8600, restype=<optimized out>, atypes=<optimized out>, avalues=0x7ff8d5dd85e0, pProc=0x7ff8eca11980 <JupyROOTExecutor>, flags=4353) at /usr/local/src/conda/python-3.8.3/Modules/_ctypes/callproc.c:871
// #26 _ctypes_callproc (pProc=<optimized out>, argtuple=<optimized out>, flags=<optimized out>, argtypes=<optimized out>, restype=<optimized out>, checker=<optimized out>) at /usr/local/src/conda/python-3.8.3/Modules/_ctypes/callproc.c:1199
// #27 0x00007ff8ee0ac0db in PyCFuncPtr_call (self=<optimized out>, inargs=<optimized out>, kwds=0x0) at /usr/local/src/conda/python-3.8.3/Modules/_ctypes/_ctypes.c:4201
// #28 0x000056141efcd25f in _PyObject_MakeTpCall (callable=0x7ff8dc3aa340, args=<optimized out>, nargs=<optimized out>, keywords=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:159
// #29 0x000056141f055719 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3467c8, callable=0x7ff8dc3aa340) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:125
// #30 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a3b9f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #31 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3469
// #32 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=2, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #33 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc347be0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #34 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc347be0, callable=0x7ff8dd9821f0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #35 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a3b9f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #36 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #37 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #38 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3465b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #39 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3465b8, callable=0x7ff8dd982040) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #40 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a3b9f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #41 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #42 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #43 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3b7fb8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #44 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3b7fb8, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #45 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561424a3b9f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #46 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #47 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #48 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d5dd8df8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #49 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d5dd8df8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #50 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #51 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd3de580, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #52 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dc35c5a0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #53 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #54 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #55 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 7 (Thread 0x7ff8d67fc700 (LWP 119071)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=29, events=0x7ff8d67fb1f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 6 (Thread 0x7ff8d6ffd700 (LWP 119070)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=27, events=0x7ff8d6ffc1f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 5 (Thread 0x7ff8d77fe700 (LWP 119069)):
// #0  0x00007ff8f039daff in __GI___poll (fds=0x7ff8d77fd5f0, nfds=2, timeout=-1) at ../sysdeps/unix/sysv/linux/poll.c:29
// #1  0x00007ff8dd91e27c in zmq_poll () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd8ef772 in zmq::proxy(zmq::socket_base_t*, zmq::socket_base_t*, zmq::socket_base_t*, zmq::socket_base_t*) () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8dd7c8a3b in __pyx_pw_3zmq_7backend_6cython_7_device_3proxy () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/_device.cpython-38-x86_64-linux-gnu.so
// #4  0x00007ff8dd7ca809 in __pyx_pw_3zmq_7backend_6cython_7_device_1device () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/_device.cpython-38-x86_64-linux-gnu.so
// #5  0x000056141efcd25f in _PyObject_MakeTpCall (callable=0x7ff8dd95d6c0, args=<optimized out>, nargs=<optimized out>, keywords=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:159
// #6  0x000056141f055719 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3c7f58, callable=0x7ff8dd95d6c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:125
// #7  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423462670) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #8  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3469
// #9  0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #10 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3c5bb8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #11 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3c5bb8, callable=0x7ff8dd551dc0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #12 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423462670) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #13 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #14 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #15 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3d3378, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #16 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3d3378, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #17 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423462670) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #18 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #19 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #20 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d77fddf8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #21 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d77fddf8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #22 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #23 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8ef140480, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #24 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dd431870) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #25 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #26 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #27 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 4 (Thread 0x7ff8d7fff700 (LWP 119068)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=19, events=0x7ff8dd431690, maxevents=3, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8f04a816c in select_epoll_poll_impl.isra.4 (maxevents=<optimized out>, timeout_obj=<optimized out>) at /usr/local/src/conda/python-3.8.3/Modules/selectmodule.c:1558
// #2  select_epoll_poll (self=0x7ff8dd42c730, args=<optimized out>, nargs=<optimized out>, kwnames=<optimized out>) at /usr/local/src/conda/python-3.8.3/Modules/clinic/selectmodule.c.h:859
// #3  0x000056141efff650 in method_vectorcall_FASTCALL_KEYWORDS (func=<optimized out>, args=0x561424fe0ff8, nargsf=<optimized out>, kwnames=0x0) at /tmp/build/80754af9/python_1593706424329/work/Objects/descrobject.c:371
// #4  0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561424fe0ff8, callable=0x7ff8ef6d7900) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #5  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #6  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #7  0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef4e9ea0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8d00011c0, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef4e6a48, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8ef6d5330, qualname=0x7ff8ef4ea670) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #8  0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d00011b0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #9  0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8d00011b0, callable=0x7ff8ef4f1430) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #10 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #11 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #12 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #13 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3ce760, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #14 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3ce760, callable=0x7ff8ee7a6c10) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #15 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #16 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #17 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #18 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3ce580, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #19 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3ce580, callable=0x7ff8ee7a50d0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #20 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #21 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #22 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #23 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3d1358, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #24 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3d1358, callable=0x7ff8dd6e2790) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #25 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #26 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #27 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #28 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d7ffe8c8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #29 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d7ffe8c8, callable=0x7ff8dd54f790) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #30 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #31 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd43f840, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #32 0x000056141f0531dc in do_call_core (kwdict=0x7ff8dd43f940, callargs=0x7ff8ef8e0040, func=0x7ff8dd43f840, tstate=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:5010
// #33 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3559
// #34 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #35 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3c57b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #36 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3c57b8, callable=0x7ff8ef65f430) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #37 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #38 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #39 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #40 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd3ca8b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #41 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dd3ca8b8, callable=0x7ff8ef65f700) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #42 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x561423477f50) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #43 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #44 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #45 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8d7ffedf8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #46 0x000056141f01b7e7 in _PyObject_Vectorcall (kwnames=0x0, nargsf=1, args=0x7ff8d7ffedf8, callable=0x7ff8ef65f4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #47 method_vectorcall (method=<optimized out>, args=0x7ff8ef8e0058, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:67
// #48 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dd436d00, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #49 0x000056141f0c530e in t_bootstrap (boot_raw=0x7ff8dd4315d0) at /tmp/build/80754af9/python_1593706424329/work/Modules/_threadmodule.c:1002
// #50 0x000056141f071e38 in pythread_wrapper (arg=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/thread_pthread.h:232
// #51 0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #52 0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 3 (Thread 0x7ff8dcbc2700 (LWP 119067)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=10, events=0x7ff8dcbc11f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 2 (Thread 0x7ff8dd3c3700 (LWP 119066)):
// #0  0x00007ff8f03aa5ce in epoll_wait (epfd=8, events=0x7ff8dd3c21f0, maxevents=256, timeout=-1) at ../sysdeps/unix/sysv/linux/epoll_wait.c:30
// #1  0x00007ff8dd8d85ed in zmq::epoll_t::loop() () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #2  0x00007ff8dd91041f in thread_routine () from /home/mstorresh/anaconda3/lib/python3.8/site-packages/zmq/backend/cython/../../../../../libzmq.so.5
// #3  0x00007ff8f0483609 in start_thread (arg=<optimized out>) at pthread_create.c:477
// #4  0x00007ff8f03aa293 in clone () at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
//
// Thread 1 (Thread 0x7ff8f011e740 (LWP 119047)):
// #0  0x00007ff8f03a012b in __GI___select (nfds=0, readfds=0x0, writefds=0x0, exceptfds=0x0, timeout=0x7ffee3a14d80) at ../sysdeps/unix/sysv/linux/select.c:41
// #1  0x000056141f0c6643 in pysleep (secs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/timemodule.c:1849
// #2  time_sleep (self=<optimized out>, obj=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/timemodule.c:338
// #3  0x000056141efd01c5 in cfunction_vectorcall_O (func=0x7ff8ef898090, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/methodobject.c:482
// #4  0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3791e0, callable=0x7ff8ef898090) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #5  call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #6  _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #7  0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8e80ce5b0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x5614249cbda0, kwcount=<optimized out>, kwstep=1, defs=0x7ff8e80cd398, defcount=2, kwdefs=0x0, closure=0x0, name=0x7ff8e80cc850, qualname=0x7ff8e80cc850) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #8  0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x5614249cbd70, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #9  0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x5614249cbd70, callable=0x7ff8e80cb940) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #10 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #11 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #12 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8e80ce3a0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x56142341e0e8, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef6c2bc8, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8e809b4e0, qualname=0x7ff8e80a53f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// ...
// #64 0x000056141f0babde in partial_fastcall.isra.2 (kwargs=0x0, nargs=<optimized out>, args=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/_functoolsmodule.c:169
// #65 partial_call (pto=0x7ff8dc353040, args=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/_functoolsmodule.c:224
// #66 0x000056141efcd25f in _PyObject_MakeTpCall (callable=0x7ff8dc353040, args=<optimized out>, nargs=<optimized out>, keywords=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:159
// #67 0x000056141f0515e5 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561425149060, callable=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:125
// #68 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #69 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #70 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=2, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #71 _PyFunction_Vectorcall (func=<optimized out>, stack=0x561424aa8630, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #72 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561424aa8630, callable=0x7ff8dd6cd4c0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #73 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #74 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #75 0x000056141f01a7af in _PyEval_EvalCodeWithName (_co=0x7ff8dd76a3a0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8dd4205e8, kwcount=<optimized out>, kwstep=1, defs=0x0, defcount=0, kwdefs=0x0, closure=0x7ff8dd3f1700, name=0x7ff8ef7a6cb0, qualname=0x7ff8dd766390) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #76 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dd4205e0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #77 0x000056141ef0def9 in _PyObject_Vectorcall (callable=0x7ff8dd3d8310, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #78 0x000056141ef1c0a7 in context_run (self=0x7ff8dc351bc0, args=0x7ff8dd4205d8, nargs=2, kwnames=0x0) at /tmp/build/80754af9/python_1593706424329/work/Python/context.c:634
// #79 0x000056141efd0344 in cfunction_vectorcall_FASTCALL_KEYWORDS (func=0x7ff8dc0960e0, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/methodobject.c:437
// #80 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8dc0960e0, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #81 0x000056141f056611 in do_call_core (kwdict=0x0, callargs=0x7ff8dd4205c0, func=0x7ff8dc0960e0, tstate=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4983
// #82 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3559
// #83 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #84 _PyFunction_Vectorcall (func=<optimized out>, stack=0x561424d41c08, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #85 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561424d41c08, callable=0x7ff8ee86d430) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #86 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #87 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #88 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #89 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc3681c0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #90 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc3681c0, callable=0x7ff8ee7a6c10) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #91 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #92 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #93 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #94 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8dc345ee0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #95 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8dc345ee0, callable=0x7ff8ee7a50d0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #96 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #97 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #98 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #99 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8ef5b4bc8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #100 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8ef5b4bc8, callable=0x7ff8dd6e2790) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #101 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #102 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #103 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=1, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #104 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8eec4d9d0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #105 0x000056141ef8f56d in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8eec4d9d0, callable=0x7ff8dd534c10) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #106 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #107 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3486
// #108 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef158190, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x7ff8ef6c2b68, kwargs=0x7ff8dd5031b8, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef06ace8, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8ef06bc30, qualname=0x7ff8ef06d530) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #109 0x000056141f01b620 in _PyFunction_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, stack=0x7ff8dd5031b0, func=0x7ff8ef004b80) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #110 _PyObject_Vectorcall (kwnames=<optimized out>, nargsf=<optimized out>, args=0x7ff8dd5031b0, callable=0x7ff8ef004b80) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #111 method_vectorcall (method=<optimized out>, args=0x7ff8dd5031b8, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/classobject.c:60
// #112 0x000056141ef9050b in _PyObject_Vectorcall (kwnames=0x7ff8ef6c2b50, nargsf=<optimized out>, args=<optimized out>, callable=0x7ff8ef1af280) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #113 call_function (kwnames=0x7ff8ef6c2b50, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #114 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3515
// #115 0x000056141f01b16b in function_code_fastcall (globals=<optimized out>, nargs=0, args=<optimized out>, co=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:283
// #116 _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8ef780db0, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:410
// #117 0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x7ff8ef780db0, callable=0x7ff8dd4155e0) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #118 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #119 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #120 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8e80cedf0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x0, kwcount=<optimized out>, kwstep=2, defs=0x0, defcount=0, kwdefs=0x0, closure=0x0, name=0x0, qualname=0x0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #121 0x000056141f01b054 in PyEval_EvalCodeEx (_co=<optimized out>, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kws=<optimized out>, kwcount=0, defs=0x0, defcount=0, kwdefs=0x0, closure=0x0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4327
// #122 0x000056141f0a95bc in PyEval_EvalCode (co=<optimized out>, globals=<optimized out>, locals=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:718
// #123 0x000056141f0de6f3 in builtin_exec_impl.isra.14 (locals=0x7ff8ef8910c0, globals=0x7ff8ef8910c0, source=0x7ff8e80cedf0) at /tmp/build/80754af9/python_1593706424329/work/Python/bltinmodule.c:1033
// #124 builtin_exec (module=<optimized out>, args=<optimized out>, nargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/clinic/bltinmodule.c.h:396
// #125 0x000056141efd0039 in cfunction_vectorcall_FASTCALL (func=0x7ff8ef8af590, args=<optimized out>, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/methodobject.c:422
// #126 0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561421cc5ad0, callable=0x7ff8ef8af590) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #127 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #128 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #129 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef73c0e0, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x561421159c80, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef72b5a8, defcount=5, kwdefs=0x0, closure=0x0, name=0x7ff8ef72f4f0, qualname=0x7ff8ef72f4f0) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #130 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x561421159c58, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #131 0x000056141ef8f819 in _PyObject_Vectorcall (kwnames=0x0, nargsf=<optimized out>, args=0x561421159c58, callable=0x7ff8ef71b940) at /tmp/build/80754af9/python_1593706424329/work/Include/cpython/abstract.h:127
// #132 call_function (kwnames=0x0, oparg=<optimized out>, pp_stack=<synthetic pointer>, tstate=0x5614210b9f90) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4963
// #133 _PyEval_EvalFrameDefault (f=<optimized out>, throwflag=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:3500
// #134 0x000056141f01a2a2 in _PyEval_EvalCodeWithName (_co=0x7ff8ef743450, globals=<optimized out>, locals=<optimized out>, args=<optimized out>, argcount=<optimized out>, kwnames=0x0, kwargs=0x7ff8ef7412a8, kwcount=<optimized out>, kwstep=1, defs=0x7ff8ef7e7dd8, defcount=1, kwdefs=0x0, closure=0x0, name=0x7ff8ef72b490, qualname=0x7ff8ef72b490) at /tmp/build/80754af9/python_1593706424329/work/Python/ceval.c:4298
// #135 0x000056141f01b243 in _PyFunction_Vectorcall (func=<optimized out>, stack=0x7ff8ef741298, nargsf=<optimized out>, kwnames=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:435
// #136 0x000056141efcca41 in PyVectorcall_Call (callable=0x7ff8ef6c3b80, tuple=<optimized out>, kwargs=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Objects/call.c:199
// #137 0x000056141f0dbf76 in pymain_run_module (modname=<optimized out>, set_argv0=1) at /tmp/build/80754af9/python_1593706424329/work/Modules/main.c:308
// #138 0x000056141f0de1b7 in pymain_run_python (exitcode=0x7ffee3a17d80) at /tmp/build/80754af9/python_1593706424329/work/Modules/main.c:565
// #139 Py_RunMain () at /tmp/build/80754af9/python_1593706424329/work/Modules/main.c:650
// #140 0x000056141f0de389 in Py_BytesMain (argc=<optimized out>, argv=<optimized out>) at /tmp/build/80754af9/python_1593706424329/work/Modules/main.c:1096
// #141 0x00007ff8f02af0b3 in __libc_start_main (main=0x56141efa6040 <main>, argc=5, argv=0x7ffee3a17f88, init=<optimized out>, fini=<optimized out>, rtld_fini=<optimized out>, stack_end=0x7ffee3a17f78) at ../csu/libc-start.c:308
// #142 0x000056141f06e553 in _start () at ../sysdeps/x86_64/elf/start.S:103
// Error in <HandleInterpreterException>: Trying to access a pointer that points to an invalid memory address..
// Execution of your code was aborted.
// input_line_152:3:1: warning: invalid memory pointer passed to a callee:
// canvas->Draw();
// ^~~~~~
